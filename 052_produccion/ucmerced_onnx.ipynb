# %% [markdown]
# # UC Merced
#
# En este notebook vamos a entrenar un modelo de clasificació de imágenes aéreas.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## El dataset

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in /usr/local/lib/python3.6/dist-packages (3.2)

# %%
import wget

url = 'https://mymldatasets.s3.eu-de.cloud-object-storage.appdomain.cloud/UCMerced_LandUse.zip'
wget.download(url)
# Out:
# 'UCMerced_LandUse (1).zip'

# %%
import zipfile
with zipfile.ZipFile('UCMerced_LandUse.zip', 'r') as zip_ref:
    zip_ref.extractall('.')

# %%
import os
from pathlib import Path

PATH = Path('dataset/Images')

labels = os.listdir(PATH)
labels, len(labels)
# Out:
# (['sparseresidential',
#   'mediumresidential',
#   'agricultural',
#   'airplane',
#   'buildings',
#   'mobilehomepark',
#   'baseballdiamond',
#   'golfcourse',
#   'beach',
#   'storagetanks',
#   'forest',
#   'runway',
#   'denseresidential',
#   'freeway',
#   'tenniscourt',
#   'harbor',
#   'chaparral',
#   'river',
#   'intersection',
#   'overpass',
#   'parkinglot'],
#  21)

# %%
for label in labels:
    items = os.listdir(PATH/label)
    print(label, ':', len(items))
# Out:
# sparseresidential : 100
# mediumresidential : 100
# agricultural : 100
# airplane : 100
# buildings : 100
# mobilehomepark : 100
# baseballdiamond : 100
# golfcourse : 100
# beach : 100
# storagetanks : 100
# forest : 100
# runway : 100
# denseresidential : 100
# freeway : 100
# tenniscourt : 100
# harbor : 100
# chaparral : 100
# river : 100
# intersection : 100
# overpass : 100
# parkinglot : 100

# %% [markdown]
# Nuestro dataset está compuesto por imágenes aéreas. Para cada una tenemos una etiqueta. Existen 21 clases diferentes, y tenemos 100 muestras para cada etiqueta.

# %%
import pandas as pd

img_paths, cls = [], []
for i, label in enumerate(labels):
    names = os.listdir(PATH/label)
    img_paths += [PATH/label/name for name in names]
    cls += [i for name in names]
    
df = pd.DataFrame({'img': img_paths, 'label': cls})
df.sample(5)
# Out:
#                                                     img  label
# 876                    dataset/Images/beach/beach11.tif      8
# 1105                 dataset/Images/runway/runway22.tif     11
# 1865     dataset/Images/intersection/intersection64.tif     18
# 45    dataset/Images/sparseresidential/sparseresiden...      0
# 110   dataset/Images/mediumresidential/mediumresiden...      1

# %%
len(df)
# Out:
# 2100

# %%
import matplotlib.pyplot as plt
from skimage import io
import random

r, c = 3, 4
fig = plt.figure(figsize=(2*c, 2*r))
for _r in range(r):
    for _c in range(c):
        ax = plt.subplot(r, c, _r*c + _c + 1)
        ix = random.randint(0, len(df)-1)
        img_path, label = df['img'][ix], df['label'][ix]
        img = io.imread(img_path)
        plt.imshow(img)
        plt.title(labels[label], color="white")
        plt.axis("off")
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

train_df, val_df = train_test_split(df, test_size=0.2, shuffle=True)
len(train_df), len(val_df)
# Out:
# (1680, 420)

# %%
import torch

class Dataset(torch.utils.data.Dataset):
    def __init__(self, imgs, labels, trans):
        self.imgs = imgs 
        self.labels = labels
        self.trans = trans
    
    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, ix):
        img = io.imread(self.imgs[ix]) 
        label = self.labels[ix]
        img = self.trans(image=img)['image']         
        return torch.from_numpy(img / 255.).permute(2,0,1).float(), torch.tensor(label).long()

# %%
import albumentations as A

trans = A.Compose([
    A.Resize(224,224),
    A.VerticalFlip(p=0.5)
])

dataset = {
    'train': Dataset(train_df['img'].values, train_df['label'].values, trans),
    'val': Dataset(val_df['img'].values, val_df['label'].values, trans)
}

len(dataset['train']), len(dataset['val'])
# Out:
# (1680, 420)

# %%
r, c = 3, 4
fig = plt.figure(figsize=(2*c, 2*r))
for _r in range(r):
    for _c in range(c):
        ax = plt.subplot(r, c, _r*c + _c + 1)
        ix = random.randint(0, len(dataset['train'])-1)
        img, label = dataset['train'][ix]
        plt.imshow(img.permute(1,2,0))
        plt.title(labels[label.item()], color="white")
        plt.axis("off")
plt.tight_layout()
plt.show()

# %%
bs, nw = 32, 4
dataloader = {
    'train': torch.utils.data.DataLoader(dataset['train'], batch_size=bs, shuffle=True, num_workers=nw, pin_memory=True),
    'val': torch.utils.data.DataLoader(dataset['val'], batch_size=bs, shuffle=False, num_workers=nw, pin_memory=True)
}

imgs, labs = next(iter(dataloader['train']))

imgs.shape, imgs.dtype, imgs.max(), imgs.min(), labs.shape
# Out:
# (torch.Size([32, 3, 224, 224]),
#  torch.float32,
#  tensor(1.),
#  tensor(0.),
#  torch.Size([32]))

# %% [markdown]
# ## El modelo

# %%
import torchvision

class Model(torch.nn.Module):
    def __init__(self, labels):
      super().__init__()
      self.labels = labels
      self.resnet = torchvision.models.resnet18(pretrained=True)        
      self.resnet.fc = torch.nn.Linear(512, len(self.labels))

    def forward(self, x):
      return self.resnet(x)

# %%
model = Model(labels)

outputs = model(torch.randn(32, 3, 224, 224))
outputs.shape
# Out:
# torch.Size([32, 21])

# %% [markdown]
# ## Entrenamiento

# %%
from tqdm import tqdm_notebook as tqdm
import numpy as np
device = "cuda" if torch.cuda.is_available() else "cpu"

def fit(model, dataloader, epochs=5, lr=3e-4):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = torch.nn.CrossEntropyLoss()
    model.to(device)
    hist = {'loss': [], 'acc': [], 'test_loss': [], 'test_acc': []}
    best_acc = 0.
    for epoch in range(1, epochs+1):
      bar = tqdm(dataloader['train'])
      train_loss, train_acc = [], []
      model.train()
      for imgs, labs in bar:
        imgs, labs = imgs.to(device), labs.to(device)
        optimizer.zero_grad()
        y_hat = model(imgs)
        loss = criterion(y_hat, labs)
        loss.backward()
        optimizer.step()
        acc = (torch.argmax(y_hat, axis=1) == labs).sum().item() / len(labs)
        train_loss.append(loss.item())
        train_acc.append(acc)
        bar.set_description(f"loss {np.mean(train_loss):.5f} acc {np.mean(train_acc):.5f}")
      hist['loss'].append(np.mean(train_loss))
      hist['acc'].append(np.mean(train_acc))
      bar = tqdm(dataloader['val'])
      test_loss, test_acc = [], []
      model.eval()
      with torch.no_grad():
        for imgs, labs in bar:
          imgs, labs = imgs.to(device), labs.to(device)
          y_hat = model(imgs)
          loss = criterion(y_hat, labs)
          acc = (torch.argmax(y_hat, axis=1) == labs).sum().item() / len(labs)
          test_loss.append(loss.item())
          test_acc.append(acc)
          bar.set_description(f"test_loss {np.mean(test_loss):.5f} test_acc {np.mean(test_acc):.5f}")
      if np.mean(test_acc) > best_acc:
        best_acc = np.mean(test_acc) 
        torch.save(model.state_dict(), 'model.pth')
      hist['test_loss'].append(np.mean(test_loss))
      hist['test_acc'].append(np.mean(test_acc))
      print(f"\nEpoch {epoch}/{epochs} loss {np.mean(train_loss):.5f} acc {np.mean(train_acc):.5f} test_loss {np.mean(test_loss):.5f} test_acc {np.mean(test_acc):.5f}")
    return hist

# %%
model = Model(labels)
hist = fit(model, dataloader)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=53.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# Epoch 1/5 loss 0.73191 acc 0.79599 test_loss 0.30450 test_acc 0.91518
# HBox(children=(FloatProgress(value=0.0, max=53.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# Epoch 2/5 loss 0.17443 acc 0.95106 test_loss 0.21129 test_acc 0.93750
# HBox(children=(FloatProgress(value=0.0, max=53.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# Epoch 3/5 loss 0.13343 acc 0.96226 test_loss 0.16074 test_acc 0.94866
# HBox(children=(FloatProgress(value=0.0, max=53.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# Epoch 4/5 loss 0.10216 acc 0.97229 test_loss 0.11878 test_acc 0.96652
# HBox(children=(FloatProgress(value=0.0, max=53.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# Epoch 5/5 loss 0.08195 acc 0.98054 test_loss 0.16098 test_acc 0.94643

# %%
df = pd.DataFrame(hist)
df.plot(grid=True)
plt.show()

# %% [markdown]
# ## Evaluación

# %%
model.load_state_dict(torch.load('model.pth'))
model.to(device)
model.eval()
with torch.no_grad():
  bar = tqdm(dataloader['val'])
  test_acc = []
  for imgs, labs in bar:
    imgs, labs = imgs.to(device), labs.to(device)
    y_hat = model(imgs)
    acc = (torch.argmax(y_hat, axis=1) == labs).sum().item() / len(labs)
    test_acc.append(acc)
  print(f'acc {np.mean(test_acc):.5f}')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# acc 0.96875

# %%
r, c = 3, 4
fig = plt.figure(figsize=(2*c, 2*r))
for _r in range(r):
    for _c in range(c):
        ax = plt.subplot(r, c, _r*c + _c + 1)
        ix = random.randint(0, len(dataset['val'])-1)
        img, label = dataset['val'][ix]
        y_hat = model(img.unsqueeze(0).to(device))
        lab = torch.argmax(y_hat, axis=1)[0].item()
        plt.imshow(img.permute(1,2,0))
        plt.title(f'{label}/{lab}', color="red" if label != lab else "green")
        plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exportar modelo

# %%
torch.jit.save(torch.jit.script(model.cpu()), 'model.zip')

# %%
loaded_model = torch.jit.load('model.zip')

# %%
loaded_model.to(device)
loaded_model.eval()
with torch.no_grad():
  bar = tqdm(dataloader['val'])
  test_acc = []
  for imgs, labs in bar:
    imgs, labs = imgs.to(device), labs.to(device)
    y_hat = loaded_model(imgs)
    acc = (torch.argmax(y_hat, axis=1) == labs).sum().item() / len(labs)
    test_acc.append(acc)
  print(f'acc {np.mean(test_acc):.5f}')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# acc 0.96875

# %%
class Preprocess(torch.nn.Module):
  def __init__(self):
    super().__init__() 
  def forward(self, x):
    # esperamos un tensor con dimensiones [224, 224, 4]
    # de tipo float32 sin normalizar [0 - 255]
    x = (x[...,:3] / 255.)
    x = x.permute(2, 0, 1)
    x = x.unsqueeze(0)
    return x 

class Postprocess(torch.nn.Module):
  def __init__(self):
    super().__init__() 
    self.softmax = torch.nn.Softmax(dim=1)
  def forward(self, x):
    return self.softmax(x)

# %%
dummy_input = torch.randint(0, 256, (224, 224, 4)).float()
#dummy_input = torch.randint(0, 256, (1, 3, 224, 224)).float()
#dummy_input = torch.randn((3, 224, 224))
#print(dummy_input.shape, dummy_input.dtype, dummy_input.max(), dummy_input.min())

model.cpu().eval()
onnx_model = torch.nn.Sequential(
    Preprocess(),
    model,
    Postprocess()
)
torch.onnx.export(onnx_model, dummy_input, "my_model.onnx", input_names=['input'], output_names=['outputs'])

# %%
import onnxruntime as ort

ort_session = ort.InferenceSession("my_model.onnx")
test_acc = 0
ds_l = len(dataset['val'])
for img, lab in tqdm(dataset['val']):
  # add new channel to simulate alpha
  img = torch.cat([img, torch.zeros(1, img.shape[1], img.shape[2])])
  # unnormalize 
  img = (img * 255.).permute(1, 2, 0).numpy()
  #print(img.shape, img.dtype, img.max(), img.min())
  #img = (img * 255.).unsqueeze(0).numpy()
  #img = img.numpy()
  #img = img.unsqueeze(0).numpy()
  outputs = ort_session.run(None, {'input': img})
  pred = np.argmax(outputs[0])
  test_acc += (pred == lab.item())
print(f'acc {(test_acc / ds_l):.5f}')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=420.0), HTML(value='')))
# acc 0.96190

# %%
# !pip install onnx
# !pip install onnxruntime
# Out:
# Requirement already satisfied: onnx in /usr/local/lib/python3.6/dist-packages (1.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from onnx) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from onnx) (1.18.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from onnx) (3.12.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.6/dist-packages (from onnx) (3.7.4.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->onnx) (50.3.2)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.6/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.6/dist-packages (from onnxruntime) (1.18.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from onnxruntime) (3.12.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->onnxruntime) (50.3.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf->onnxruntime) (1.15.0)
